# %%
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
#                                                                             [100%]
# ================================================== warnings summary ===================================================
# test_phase9.py: 108 warnings
#   C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages\joblib\numpy_pickle.py:207: DeprecationWarning: Setting the shape on a NumPy array has been deprecated in NumPy 2.5.
#   As an alternative, you can create a new view using np.reshape (with copy=False if needed).
#     array.shape = self.shape
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# 37 passed, 108 warnings in 23.27s

# %%
# Out:
# {'agent_name': 'PredictionAgent', 'status': 'PASS WITH LIMITATIONS', 'finding_type': 'predictions', 'summary': 'Property 1: predicted valuation ₹11,172,758 (-2.8% vs asking price); predicted rent ₹31,346/mo.', 'metrics': {'predicted_valuation': 11172758.0, 'predicted_rent': 31346.0, 'valuation_gap_pct': -2.77}, 'evidence_ids': [], 'source': 'models/valuation_v1_gbr.joblib + rent_v1_gbr.joblib (Phase 4)', 'confidence': 70.0, 'limitations': ['dom_v1_gbr is REJECTED per the Phase 4 model registry -- never called by this agent, regardless of what any caller requests.', 'sale_probability_v1_gbr is REJECTED per the Phase 4 model registry -- never called by this agent, regardless of what any caller requests.', "price_forecast_v1_gbr_6m and demand_forecast_v1_gbr_6m are locality-level (not property-level) and CONDITIONAL -- available via the Market Agent's underlying data if needed, but intentionally excluded from this agent's property-level predictions and from the automated decision_score.
# ...

# %%
# Out:
# Wrote C:\Users\Admin\Downloads\phase9_all_files_fixed\phase9\docs\decision_results_csv\01_decision_summary.csv (26 rows)
# Wrote C:\Users\Admin\Downloads\phase9_all_files_fixed\phase9\docs\decision_results_csv\02_component_scores.csv (128 rows)
# Wrote C:\Users\Admin\Downloads\phase9_all_files_fixed\phase9\docs\decision_results_csv\03_critical_gates.csv (104 rows)
# Wrote C:\Users\Admin\Downloads\phase9_all_files_fixed\phase9\docs\decision_results_csv\04_reasons_and_risks.csv (179 rows)
# Decision distribution: {'HOLD': 12, 'AVOID': 7, 'INVEST': 6, 'INSUFFICIENT': 1}

# %%
# Out:
# {'property_id': 101, 'decision': 'INVEST', 'decision_score': None, 'decision_confidence': None, 'market_findings': {'agent_name': 'MarketAgent', 'status': 'PASS', 'finding_type': 'market_snapshot', 'summary': 'Market conditions look favorable.', 'metrics': {}, 'evidence_ids': [], 'source': '', 'confidence': None, 'limitations': [], 'timestamp': '2026-09-05T13:08:54.555981+00:00'}, 'prediction_findings': {}, 'financial_findings': {}, 'risk_findings': {}, 'geo_findings': {}, 'evidence': {}, 'key_reasons': [], 'key_risks': [], 'critical_assumptions': [], 'conditions': [], 'recommended_actions': [], 'limitations': [], 'data_quality_status': 'UNKNOWN', 'model_status': 'UNKNOWN', 'evidence_status': 'UNKNOWN', 'component_scores': {}, 'gate_results': {}, 'timestamp': '2026-09-05T13:08:54.556223+00:00'}
